# %%
import pandas as pd
import yfinance as yf
import numpy as np
import matplotlib.pyplot as plt
import datetime
import seaborn as sns
import warnings

# %%
warnings.filterwarnings('ignore')

# %%
tickers =[ "META",'AAPL','NVDA','AMZN','GOOG','MSFT']
stock_data = yf.download(tickers, start="2020-01-01", end="2024-01-01")
# Out:
# [*********************100%***********************]  6 of 6 completed

# %%
df = stock_data

# %%
df.head()
# Out:
# Price                      Adj Close                                    \
# Ticker                          AAPL       AMZN       GOOG        META
# Date
# 2020-01-02 00:00:00+00:00  72.796036  94.900497  68.201012  209.150269
# 2020-01-03 00:00:00+00:00  72.088295  93.748497  67.866325  208.043594
# 2020-01-06 00:00:00+00:00  72.662704  95.143997  69.539726  211.961823
# 2020-01-07 00:00:00+00:00  72.320976  95.343002  69.496330  212.420425
# 2020-01-08 00:00:00+00:00  73.484352  94.598503  70.043991  214.573944
#
# Price                                                Close             \
# Ticker                           MSFT      NVDA       AAPL       AMZN
# Date
# 2020-01-02 00:00:00+00:00  153.630707  5.973122  75.087502  94.900497
# 2020-01-03 00:00:00+00:00  151.717758  5.877516  74.357498  93.748497
# 2020-01-06 00:00:00+00:00  152.109909  5.902164  74.949997  95.143997
# 2020-01-07 00:00:00+00:00  150.722992  5.973620  74.597504  95.343002
# ...

# %%
adj_close = df['Adj Close']

# %%
adj_close.describe
# Out:
# <bound method NDFrame.describe of Ticker                           AAPL        AMZN        GOOG        META  \
# Date
# 2020-01-02 00:00:00+00:00   72.796036   94.900497   68.201012  209.150269
# 2020-01-03 00:00:00+00:00   72.088295   93.748497   67.866325  208.043594
# 2020-01-06 00:00:00+00:00   72.662704   95.143997   69.539726  211.961823
# 2020-01-07 00:00:00+00:00   72.320976   95.343002   69.496330  212.420425
# 2020-01-08 00:00:00+00:00   73.484352   94.598503   70.043991  214.573944
# ...                               ...         ...         ...         ...
# 2023-12-22 00:00:00+00:00  192.656174  153.419998  142.370361  352.329163
# 2023-12-26 00:00:00+00:00  192.108856  153.410004  142.470123  353.764832
# 2023-12-27 00:00:00+00:00  192.208374  153.339996  141.093506  356.755829
# 2023-12-28 00:00:00+00:00  192.636276  153.380005  140.933899  357.244354
# 2023-12-29 00:00:00+00:00  191.591370  151.940002  140.584747  352.897491
#
# ...

# %% [markdown]
# market capitalization

# %%
open_volume = df[['Open','Volume']]

# %%
mkt = pd.DataFrame()

mkt ['AAPL_mkt'] = open_volume['Open','AAPL'] * open_volume['Volume',"AAPL"]
mkt ['AMZN_mkt'] = open_volume['Open','AMZN'] * open_volume['Volume',"AMZN"]
mkt ['GOOG_mkt'] = open_volume['Open','GOOG'] * open_volume['Volume',"GOOG"]
mkt ['META_mkt'] = open_volume['Open','META'] * open_volume['Volume',"META"]
mkt ['MSFT_mkt'] = open_volume['Open','MSFT'] * open_volume['Volume',"MSFT"]
mkt ['NVDA_mkt'] = open_volume['Open','NVDA'] * open_volume['Volume',"NVDA"]

# %%
plt.rcParams['figure.figsize'] = (20, 5)

# %%
mkt['AAPL_mkt'].plot(label ='APPLE')
mkt['AMZN_mkt'].plot(label ='APPLE')
# Out:
# <Axes: xlabel='Date'>

# %%
adj_close_AAPL = df["Adj Close",'AAPL']

# %%
plt.rcParams['figure.figsize'] = (20,5)
adj_close_AAPL.plot(color ='blue')
plt.title('AAPL Adjusted Close Trend')
plt.ylabel('Adj_close')
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>
